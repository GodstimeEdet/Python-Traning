# %%
import numpy as np
import pandas as pd

# %%
#Series 

# Series is a one-dimensional array like structure with homogeneous data.

#DataFrame   
# DataFrame is a two-dimensional array with heterogeneous data. 

#Panel

#Panel is a three-dimensional data structure with heterogeneous data. 
#It is hard to represent the panel in graphical representation. 

#But a panel can be illustrated as a container of DataFrame.

# %%
ser1 = pd.Series([10,20,30,40,50])
print(type(ser1))
ser2 = pd.Series((76,78,87,98))
ser3 = pd.Series(np.array([12,31,321,434,54,32]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
ser1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
ser1[1]
# Out:
# 20

# %%
ser3
# Out:
# 0     12
# 1     31
# 2    321
# 3    434
# 4     54
# 5     32
# dtype: int32

# %%
dict1 = {'a':1,'b':2,'c':3,'d':4}
ser4 = pd.Series(dict1)

# %%
ser4
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser4['a']
# Out:
# 1

# %%
ser5 = pd.Series([12,98,15,91,18,89],index=['a','b','c','d','e','f'])

# %%
ser5 = pd.Series([12,98,15,91,18,89],index=['a','b','c','d','e','f'])

# %%
ser5
# Out:
# a    12
# b    98
# c    15
# d    91
# e    18
# f    89
# dtype: int64

# %%
ser6 = pd.Series(index=['a','b','c','d','e','f'], [12,98,15,91,18,89])   # its mot define in pandas Series
# Out:
#   Cell In[12], line 1
#     ser6 = pd.Series(index=['a','b','c','d','e','f'], [12,98,15,91,18,89])   # its mot define in pandas Series
#                                                                          ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ### DATA FRAME

# %%
df = pd.DataFrame([[1,2,3],[4,5,6]])

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df.shape
# Out:
# (2, 3)

# %%
my_list = [['apple','sweet',100],['grapes','sour',80],['orange','tangy',60]]
df2 = pd.DataFrame(my_list,columns=['fruit','taste','price'])
df2
# Out:
#     fruit  taste  price
# 0   apple  sweet    100
# 1  grapes   sour     80
# 2  orange  tangy     60

# %%
my_dict = {'Name':['Steph','Victor','Omoh'],'class':[7,8,9],'blood_group':['A+','B+','A+']}
df3 = pd.DataFrame(my_dict)
df3
# Out:
#      Name  class blood_group
# 0   Steph      7          A+
# 1  Victor      8          B+
# 2    Omoh      9          A+

# %%
df3['Name']
# Out:
# 0     Steph
# 1    Victor
# 2      Omoh
# Name: Name, dtype: object

# %%
df3.iloc[:2]
# Out:
#      Name  class blood_group
# 0   Steph      7          A+
# 1  Victor      8          B+

# %%
#seaborn is a data visualization tool
#!pip install seaborn
import seaborn as sn   # we are importing seaborn to be able to access the sample data sets in the library

# %%
sn.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File ~\anaconda3\lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File ~\anaconda3\lib\http\client.py:1447, in HTTPSConnection.connect(self)
#    1445 "Connect to a host on a given (SSL) port."
# -> 1447 super().connect()
#    1449 if self._tunnel_host:
#
# File ~\anaconda3\lib\http\client.py:941, in HTTPConnection.connect(self)
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~\anaconda3\lib\socket.py:824, in create_connection(address, timeout, source_address)
#     823 err = None
# --> 824 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     825     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sn.get_dataset_names()
#
# File ~\anaconda3\lib\site-packages\seaborn\utils.py:512, in get_dataset_names()
#     506 """Report available example datasets, useful for reporting issues.
#     507
#     508 Requires an internet connection.
#     509
#     510 """
#     511 url = "https://github.com/mwaskom/seaborn-data"
# --> 512 with urlopen(url) as resp:
#     513     html = resp.read()
#     515 pat = r"/mwaskom/seaborn-data/blob/master/(\w*).csv"
#
# File ~\anaconda3\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\anaconda3\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\anaconda3\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\anaconda3\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
# Loading the diamonds data  

df1= sn.load_dataset('diamonds')
df1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Loading the titanic data  

df2= sn.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df2.to_csv('victor.csv')

# %%
pwd
# Out:
# 'C:\\Users\\Guest Pc\\Documents\\data science'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8681-DB28
#
#  Directory of C:\Users\Guest Pc\Documents\data science
#
# 06/20/2023  10:35 AM    <DIR>          .
# 06/20/2023  10:35 AM    <DIR>          ..
# 06/20/2023  10:09 AM    <DIR>          .ipynb_checkpoints
# 06/19/2023  12:16 PM           851,480 numpy_june_class.ipynb
# 06/20/2023  10:35 AM            44,909 pandas_class.ipynb
# 06/19/2023  11:24 AM    <DIR>          python
# 06/16/2023  10:58 AM           107,478 python class.ipynb
# 06/14/2023  11:48 AM            57,578 python_class_june_2.ipynb
# 06/16/2023  01:05 PM            61,365 titanic.csv
# 06/20/2023  10:38 AM            61,365 victor.csv
#                6 File(s)      1,184,175 bytes
#                4 Dir(s)  22,982,451,200 bytes free

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df1.shape
# Out:
# (53940, 10)

# %%
df1.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df1.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df1.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df1.head(20)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13   0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14   0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15   0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16   0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17   0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18   0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19   0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66

# %%
# converting a dataset columns to a list

cols = list(df1.columns)

# %%
cols
# Out:
# ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
ssampledata=df1.sample(50)


ssampledata.shape# inspect the properties and datatype of the features in the data using .info()


df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
ssampledata=df1.sample(50)


ssampledata.shape
# Out:
# (50, 10)

# %%
df1['cut']
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
# get unique number of labels in the cut columns

df1.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df1['cut'].unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
# getting all diamond sample that are premium
premiumSamples = df1.loc[df1['cut']  == 'Premium']

# %%
premiumSamples
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %%
priceBelow400 = df1.loc[df1['price'] < 400]

# %%
priceBelow400
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 50612   0.26  Very Good     H     VS1   62.0   56.0    399  4.08  4.11  2.54
# 50613   0.25  Very Good     D     VS2   61.1   60.0    399  4.07  4.11  2.50
# 50614   0.27  Very Good     G     VS1   58.8   57.0    399  4.25  4.36  2.53
# 50615   0.24       Good     F     VS1   62.5   60.0    399  3.96  3.98  2.48
# 50616   0.25       Good     D     VS1   57.6   60.0    399  4.15  4.18  2.40
#
# [247 rows x 10 columns]

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8681-DB28
#
#  Directory of C:\Users\Guest Pc\Documents\data science
#
# 06/20/2023  10:45 AM    <DIR>          .
# 06/20/2023  10:45 AM    <DIR>          ..
# 06/20/2023  10:09 AM    <DIR>          .ipynb_checkpoints
# 06/19/2023  12:16 PM           851,480 numpy_june_class.ipynb
# 06/20/2023  10:45 AM           107,094 pandas_class.ipynb
# 06/19/2023  11:24 AM    <DIR>          python
# 06/16/2023  10:58 AM           107,478 python class.ipynb
# 06/14/2023  11:48 AM            57,578 python_class_june_2.ipynb
# 06/16/2023  01:05 PM            61,365 titanic.csv
# 06/20/2023  10:38 AM            61,365 victor.csv
#                6 File(s)      1,246,360 bytes
#                4 Dir(s)  22,977,359,872 bytes free

# %%
titanic_dataset = pd.read_csv('titanic.csv')

# %%
titanic_dataset
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
titanic_dataset.shape
# Out:
# (891, 16)

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
cols = titanic_dataset.columns.tolist()

missingrec = titanic_dataset.isna().sum()
#dataLen = len(titanic_dataset)

for col, rec in zip(cols, missingrec):
    if rec > 0:
        print(f'{col} is missing {rec} number of samples')
    else:
        print('no missing data')
# Out:
# no missing data
# no missing data
# no missing data
# no missing data
# age is missing 177 number of samples
# no missing data
# no missing data
# no missing data
# embarked is missing 2 number of samples
# no missing data
# no missing data
# no missing data
# deck is missing 688 number of samples
# embark_town is missing 2 number of samples
# no missing data
# no missing data

# %%
len(titanic_dataset)
# Out:
# 891

# %%
titanic_dataset.isna().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
cols
# Out:
# ['Unnamed: 0',
#  'survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
titanic_dataset.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
titanic_dataset.describe().T
# Out:
#             count        mean         std   min       25%       50%    75%  \
# Unnamed: 0  891.0  445.000000  257.353842  0.00  222.5000  445.0000  667.5
# survived    891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# pclass      891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# age         714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# sibsp       891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# parch       891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# fare        891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                  max
# Unnamed: 0  890.0000
# survived      1.0000
# pclass        3.0000
# age          80.0000
# sibsp         8.0000
# parch         6.0000
# fare        512.3292

# %%
titanic_dataset.describe(include= 'object').T
# Out:
#             count unique          top freq
# sex           891      2         male  577
# embarked      889      3            S  644
# class         891      3        Third  491
# who           891      3          man  537
# deck          203      7            C   59
# embark_town   889      3  Southampton  644
# alive         891      2           no  549

# %%
titanic_dataset.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_dataset['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
titanic_dataset[['sex','age']]
# Out:
#         sex   age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
titanic_dataset
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 0          S   Third    man        True  NaN  Southampton    no  False
# 1          C   First  woman       False    C    Cherbourg   yes  False
# 2          S   Third  woman       False  NaN  Southampton   yes   True
# 3          S   First  woman       False    C  Southampton   yes  False
# 4          S   Third    man        True  NaN  Southampton    no   True
# ..       ...     ...    ...         ...  ...          ...   ...    ...
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
titanic_dataset
# Out:
#      Unnamed: 0  survived  pclass     sex    age  sibsp  parch      fare  \
# 0             0         0       3    male  22.00      1      0    7.2500
# 1             1         1       1  female  38.00      1      0   71.2833
# 2             2         1       3  female  26.00      0      0    7.9250
# 3             3         1       1  female  35.00      1      0   53.1000
# 4             4         0       3    male  35.00      0      0    8.0500
# 5             5         0       3    male    NaN      0      0    8.4583
# 6             6         0       1    male  54.00      0      0   51.8625
# 7             7         0       3    male   2.00      3      1   21.0750
# 8             8         1       3  female  27.00      0      2   11.1333
# 9             9         1       2  female  14.00      1      0   30.0708
# 10           10         1       3  female   4.00      1      1   16.7000
# 11           11         1       1  female  58.00      0      0   26.5500
# 12           12         0       3    male  20.00      0      0    8.0500
# 13           13         0       3    male  39.00      1      5   31.2750
# 14           14         0       3  female  14.00      0      0    7.8542
# 15           15         1       2  female  55.00      0      0   16.0000
# 16           16         0       3    male   2.00      4      1   29.1250
# 17           17         1       2    male    NaN      0      0   13.0000
# 18           18         0       3  female  31.00      1      0   18.0000
# 19           19         1       3  female    NaN      0      0    7.2250
# 20           20         0       2    male  35.00      0      0   26.0000
# 21           21         1       2    male  34.00      0      0   13.0000
# 22           22         1       3  female  15.00      0      0    8.0292
# 23           23         1       1    male  28.00      0      0   35.5000
# 24           24         0       3  female   8.00      3      1   21.0750
# 25           25         1       3  female  38.00      1      5   31.3875
# 26           26         0       3    male    NaN      0      0    7.2250
# 27           27         0       1    male  19.00      3      2  263.0000
# 28           28         1       3  female    NaN      0      0    7.8792
# 29           29         0       3    male    NaN      0      0    7.8958
# 30           30         0       1    male  40.00      0      0   27.7208
# 31           31         1       1  female    NaN      1      0  146.5208
# 32           32         1       3  female    NaN      0      0    7.7500
# 33           33         0       2    male  66.00      0      0   10.5000
# 34           34         0       1    male  28.00      1      0   82.1708
# 35           35         0       1    male  42.00      1      0   52.0000
# 36           36         1       3    male    NaN      0      0    7.2292
# 37           37         0       3    male  21.00      0      0    8.0500
# 38           38         0       3  female  18.00      2      0   18.0000
# 39           39         1       3  female  14.00      1      0   11.2417
# 40           40         0       3  female  40.00      1      0    9.4750
# 41           41         0       2  female  27.00      1      0   21.0000
# 42           42         0       3    male    NaN      0      0    7.8958
# 43           43         1       2  female   3.00      1      2   41.5792
# 44           44         1       3  female  19.00      0      0    7.8792
# 45           45         0       3    male    NaN      0      0    8.0500
# 46           46         0       3    male    NaN      1      0   15.5000
# 594         594         0       2    male  37.00      1      0   26.0000
# 595         595         0       3    male  36.00      1      1   24.1500
# 596         596         1       2  female    NaN      0      0   33.0000
# 597         597         0       3    male  49.00      0      0    0.0000
# 598         598         0       3    male    NaN      0      0    7.2250
# 599         599         1       1    male  49.00      1      0   56.9292
# 600         600         1       2  female  24.00      2      1   27.0000
# 601         601         0       3    male    NaN      0      0    7.8958
# 602         602         0       1    male    NaN      0      0   42.4000
# 603         603         0       3    male  44.00      0      0    8.0500
# 604         604         1       1    male  35.00      0      0   26.5500
# 605         605         0       3    male  36.00      1      0   15.5500
# 606         606         0       3    male  30.00      0      0    7.8958
# 607         607         1       1    male  27.00      0      0   30.5000
# 608         608         1       2  female  22.00      1      2   41.5792
# 609         609         1       1  female  40.00      0      0  153.4625
# 610         610         0       3  female  39.00      1      5   31.2750
# 611         611         0       3    male    NaN      0      0    7.0500
# 612         612         1       3  female    NaN      1      0   15.5000
# 613         613         0       3    male    NaN      0      0    7.7500
# 614         614         0       3    male  35.00      0      0    8.0500
# 615         615         1       2  female  24.00      1      2   65.0000
# 616         616         0       3    male  34.00      1      1   14.4000
# 617         617         0       3  female  26.00      1      0   16.1000
# 618         618         1       2  female   4.00      2      1   39.0000
# 619         619         0       2    male  26.00      0      0   10.5000
# 620         620         0       3    male  27.00      1      0   14.4542
# 621         621         1       1    male  42.00      1      0   52.5542
# 622         622         1       3    male  20.00      1      1   15.7417
# 623         623         0       3    male  21.00      0      0    7.8542
# 624         624         0       3    male  21.00      0      0   16.1000
# 625         625         0       1    male  61.00      0      0   32.3208
# 626         626         0       2    male  57.00      0      0   12.3500
# 627         627         1       1  female  21.00      0      0   77.9583
# 628         628         0       3    male  26.00      0      0    7.8958
# 629         629         0       3    male    NaN      0      0    7.7333
# ...
# 672        S  Second    man        True  NaN  Southampton    no   True
# 673        S  Second    man        True  NaN  Southampton   yes   True
# 674        S  Second    man        True  NaN  Southampton    no   True
# 675        S   Third    man        True  NaN  Southampton    no   True
# 676        S   Third    man        True  NaN  Southampton    no   True
# 677        S   Third  woman       False  NaN  Southampton   yes   True
# 678        S   Third  woman       False  NaN  Southampton    no  False
# 679        C   First    man        True    B    Cherbourg   yes  False
# 680        Q   Third  woman       False  NaN   Queenstown    no   True
# 681        C   First    man        True    D    Cherbourg   yes   True
# 682        S   Third    man        True  NaN  Southampton    no   True
# 683        S   Third  child       False  NaN  Southampton    no  False
# 684        S  Second    man        True  NaN  Southampton    no  False
# 685        C  Second    man        True  NaN    Cherbourg    no  False
# 686        S   Third  child       False  NaN  Southampton    no  False
# 687        S   Third    man        True  NaN  Southampton    no   True
# 688        S   Third    man        True  NaN  Southampton    no   True
# 689        S   First  child       False    B  Southampton   yes  False
# 690        S   First    man        True    B  Southampton   yes  False
# 691        C   Third  child       False  NaN    Cherbourg   yes  False
# 692        S   Third    man        True  NaN  Southampton   yes   True
# 693        C   Third    man        True  NaN    Cherbourg    no   True
# 694        S   First    man        True  NaN  Southampton    no   True
# 695        S  Second    man        True  NaN  Southampton    no   True
# 696        S   Third    man        True  NaN  Southampton    no   True
# 697        Q   Third  woman       False  NaN   Queenstown   yes   True
# 698        C   First    man        True    C    Cherbourg    no  False
# 699        S   Third    man        True    F  Southampton    no   True
# 700        C   First  woman       False    C    Cherbourg   yes  False
# 701        S   First    man        True    E  Southampton   yes   True
# 702        C   Third  woman       False  NaN    Cherbourg    no  False
# 703        Q   Third    man        True  NaN   Queenstown    no   True
# 704        S   Third    man        True  NaN  Southampton    no  False
# 705        S  Second    man        True  NaN  Southampton    no   True
# 706        S  Second  woman       False  NaN  Southampton   yes   True
# 707        S   First    man        True    E  Southampton   yes   True
# 708        S   First  woman       False  NaN  Southampton   yes   True
# 709        C   Third    man        True  NaN    Cherbourg   yes  False
# 710        C   First  woman       False    C    Cherbourg   yes   True
# 711        S   First    man        True    C  Southampton    no   True
# 712        S   First    man        True    C  Southampton   yes  False
# 713        S   Third    man        True  NaN  Southampton    no   True
# 714        S  Second    man        True  NaN  Southampton    no   True
# 715        S   Third    man        True    F  Southampton    no   True
# 716        C   First  woman       False    C    Cherbourg   yes   True
# 717        S  Second  woman       False    E  Southampton   yes   True
# 718        Q   Third    man        True  NaN   Queenstown    no   True
# 719        S   Third    man        True  NaN  Southampton    no   True
# 720        S  Second  child       False  NaN  Southampton   yes  False
# 721        S   Third    man        True  NaN  Southampton    no  False
# 722        S  Second    man        True  NaN  Southampton    no   True
# 723        S  Second    man        True  NaN  Southampton    no   True
# 724        S   First    man        True    E  Southampton   yes  False
# 725        S   Third    man        True  NaN  Southampton    no   True
# 726        S  Second  woman       False  NaN  Southampton   yes  False
# 727        Q   Third  woman       False  NaN   Queenstown   yes   True
# 728        S  Second    man        True  NaN  Southampton    no  False
# 729        S   Third  woman       False  NaN  Southampton    no  False
# 730        S   First  woman       False    B  Southampton   yes   True
# 731        C   Third  child       False  NaN    Cherbourg    no   True
# 732        S  Second    man        True  NaN  Southampton    no   True
# 733        S  Second    man        True  NaN  Southampton    no   True
# 734        S  Second    man        True  NaN  Southampton    no   True
# 735        S   Third    man        True  NaN  Southampton    no   True
# 736        S   Third  woman       False  NaN  Southampton    no  False
# 737        C   First    man        True    B    Cherbourg   yes   True
# 738        S   Third    man        True  NaN  Southampton    no   True
# 739        S   Third    man        True  NaN  Southampton    no   True
# 740        S   First    man        True    D  Southampton   yes   True
# 741        S   First    man        True    C  Southampton    no  False
# 742        C   First  woman       False    B    Cherbourg   yes  False
# 743        S   Third    man        True  NaN  Southampton    no  False
# 744        S   Third    man        True  NaN  Southampton   yes   True
# 745        S   First    man        True    B  Southampton    no  False
# 746        S   Third    man        True  NaN  Southampton    no  False
# 747        S  Second  woman       False  NaN  Southampton   yes   True
# 748        S   First    man        True    D  Southampton    no  False
# 749        Q   Third    man        True  NaN   Queenstown    no   True
# 750        S  Second  child       False  NaN  Southampton   yes  False
# 751        S   Third  child       False    E  Southampton   yes  False
# 752        S   Third    man        True  NaN  Southampton    no   True
# 753        S   Third    man        True  NaN  Southampton    no   True
# 754        S  Second  woman       False  NaN  Southampton   yes  False
# 755        S  Second  child       False  NaN  Southampton   yes  False
# 756        S   Third    man        True  NaN  Southampton    no   True
# 757        S  Second    man        True  NaN  Southampton    no   True
# 758        S   Third    man        True  NaN  Southampton    no   True
# 759        S   First  woman       False    B  Southampton   yes   True
# 760        S   Third    man        True  NaN  Southampton    no   True
# 761        S   Third    man        True  NaN  Southampton    no   True
# 762        C   Third    man        True  NaN    Cherbourg   yes   True
# 763        S   First  woman       False    B  Southampton   yes  False
# 764        S   Third    man        True  NaN  Southampton    no   True
# 765        S   First  woman       False    D  Southampton   yes  False
# 766        C   First    man        True  NaN    Cherbourg    no   True
# 767        Q   Third  woman       False  NaN   Queenstown    no   True
# 768        Q   Third    man        True  NaN   Queenstown    no  False
# 769        S   Third    man        True  NaN  Southampton    no   True
# 770        S   Third    man        True  NaN  Southampton    no   True
# 771        S   Third    man        True  NaN  Southampton    no   True
# 772        S  Second  woman       False    E  Southampton    no   True
# 773        C   Third    man        True  NaN    Cherbourg    no   True
# 774        S  Second  woman       False  NaN  Southampton   yes  False
# 775        S   Third    man        True  NaN  Southampton    no   True
# 776        Q   Third    man        True    F   Queenstown    no   True
# 777        S   Third  child       False  NaN  Southampton   yes   True
# 778        Q   Third    man        True  NaN   Queenstown    no   True
# 779        S   First  woman       False    B  Southampton   yes  False
# 780        C   Third  child       False  NaN    Cherbourg   yes   True
# 781        S   First  woman       False    B  Southampton   yes  False
# 782        S   First    man        True    D  Southampton    no   True
# 783        S   Third    man        True  NaN  Southampton    no  False
# 784        S   Third    man        True  NaN  Southampton    no   True
# 785        S   Third    man        True  NaN  Southampton    no   True
# 786        S   Third  woman       False  NaN  Southampton   yes   True
# 787        Q   Third  child       False  NaN   Queenstown    no  False
# 788        S   Third  child       False  NaN  Southampton   yes  False
# 789        C   First    man        True    B    Cherbourg    no   True
# 790        Q   Third    man        True  NaN   Queenstown    no   True
# 791        S  Second    man        True  NaN  Southampton    no   True
# 792        S   Third  woman       False  NaN  Southampton    no  False
# 793        C   First    man        True  NaN    Cherbourg    no   True
# 794        S   Third    man        True  NaN  Southampton    no   True
# 795        S  Second    man        True  NaN  Southampton    no   True
# 796        S   First  woman       False    D  Southampton   yes   True
# 797        S   Third  woman       False  NaN  Southampton   yes   True
# 798        C   Third    man        True  NaN    Cherbourg    no   True
# 799        S   Third  woman       False  NaN  Southampton    no  False
# 800        S  Second    man        True  NaN  Southampton    no   True
# 801        S  Second  woman       False  NaN  Southampton   yes  False
# 802        S   First  child       False    B  Southampton   yes  False
# 803        C   Third  child       False  NaN    Cherbourg   yes  False
# 804        S   Third    man        True  NaN  Southampton   yes   True
# 805        S   Third    man        True  NaN  Southampton    no   True
# 806        S   First    man        True    A  Southampton    no   True
# 807        S   Third  woman       False  NaN  Southampton    no   True
# 808        S  Second    man        True  NaN  Southampton    no   True
# 809        S   First  woman       False    E  Southampton   yes  False
# 810        S   Third    man        True  NaN  Southampton    no   True
# 811        S   Third    man        True  NaN  Southampton    no   True
# 812        S  Second    man        True  NaN  Southampton    no   True
# 813        S   Third  child       False  NaN  Southampton    no  False
# 814        S   Third    man        True  NaN  Southampton    no   True
# 815        S   First    man        True    B  Southampton    no   True
# 816        S   Third  woman       False  NaN  Southampton    no   True
# 817        C  Second    man        True  NaN    Cherbourg    no  False
# 818        S   Third    man        True  NaN  Southampton    no   True
# 819        S   Third  child       False  NaN  Southampton    no  False
# 820        S   First  woman       False    B  Southampton   yes  False
# 821        S   Third    man        True  NaN  Southampton   yes   True
# 822        S   First    man        True  NaN  Southampton    no   True
# 823        S   Third  woman       False    E  Southampton   yes  False
# 824        S   Third  child       False  NaN  Southampton    no  False
# 825        Q   Third    man        True  NaN   Queenstown    no   True
# 826        S   Third    man        True  NaN  Southampton    no   True
# 827        C  Second  child       False  NaN    Cherbourg   yes  False
# 828        Q   Third    man        True  NaN   Queenstown   yes   True
# 829      NaN   First  woman       False    B          NaN   yes   True
# 830        C   Third  child       False  NaN    Cherbourg   yes  False
# 831        S  Second  child       False  NaN  Southampton   yes  False
# 832        C   Third    man        True  NaN    Cherbourg    no   True
# 833        S   Third    man        True  NaN  Southampton    no   True
# 834        S   Third    man        True  NaN  Southampton    no   True
# 835        C   First  woman       False    E    Cherbourg   yes  False
# 836        S   Third    man        True  NaN  Southampton    no   True
# 837        S   Third    man        True  NaN  Southampton    no   True
# 838        S   Third    man        True  NaN  Southampton   yes   True
# 839        C   First    man        True    C    Cherbourg   yes   True
# 840        S   Third    man        True  NaN  Southampton    no   True
# 841        S  Second    man        True  NaN  Southampton    no   True
# 842        C   First  woman       False  NaN    Cherbourg   yes   True
# 843        C   Third    man        True  NaN    Cherbourg    no   True
# 844        S   Third    man        True  NaN  Southampton    no   True
# 845        S   Third    man        True  NaN  Southampton    no   True
# 846        S   Third    man        True  NaN  Southampton    no  False
# 847        C   Third    man        True  NaN    Cherbourg    no   True
# 848        S  Second    man        True  NaN  Southampton    no  False
# 849        C   First  woman       False    C    Cherbourg   yes  False
# 850        S   Third  child       False  NaN  Southampton    no  False
# 851        S   Third    man        True  NaN  Southampton    no   True
# 852        C   Third  child       False  NaN    Cherbourg    no  False
# 853        S   First  woman       False    D  Southampton   yes  False
# 854        S  Second  woman       False  NaN  Southampton    no  False
# 855        S   Third  woman       False  NaN  Southampton   yes  False
# 856        S   First  woman       False  NaN  Southampton   yes  False
# 857        S   First    man        True    E  Southampton   yes   True
# 858        C   Third  woman       False  NaN    Cherbourg   yes  False
# 859        C   Third    man        True  NaN    Cherbourg    no   True
# 860        S   Third    man        True  NaN  Southampton    no  False
# 861        S  Second    man        True  NaN  Southampton    no  False
# 862        S   First  woman       False    D  Southampton   yes   True
# 863        S   Third  woman       False  NaN  Southampton    no  False
# 864        S  Second    man        True  NaN  Southampton    no   True
# 865        S  Second  woman       False  NaN  Southampton   yes   True
# 866        C  Second  woman       False  NaN    Cherbourg   yes  False
# 867        S   First    man        True    A  Southampton    no   True
# 868        S   Third    man        True  NaN  Southampton    no   True
# 869        S   Third  child       False  NaN  Southampton   yes  False
# 870        S   Third    man        True  NaN  Southampton    no   True
# 871        S   First  woman       False    D  Southampton   yes  False
# 872        S   First    man        True    B  Southampton    no   True
# 873        S   Third    man        True  NaN  Southampton    no   True
# 874        C  Second  woman       False  NaN    Cherbourg   yes  False
# 875        C   Third  child       False  NaN    Cherbourg   yes   True
# 876        S   Third    man        True  NaN  Southampton    no   True
# 877        S   Third    man        True  NaN  Southampton    no   True
# 878        S   Third    man        True  NaN  Southampton    no   True
# 879        C   First  woman       False    C    Cherbourg   yes  False
# 880        S  Second  woman       False  NaN  Southampton   yes  False
# 881        S   Third    man        True  NaN  Southampton    no   True
# 882        S   Third  woman       False  NaN  Southampton    no   True
# 883        S  Second    man        True  NaN  Southampton    no   True
# 884        S   Third    man        True  NaN  Southampton    no   True
# 885        Q   Third  woman       False  NaN   Queenstown    no  False
# 886        S  Second    man        True  NaN  Southampton    no   True
# 887        S   First  woman       False    B  Southampton   yes   True
# 888        S   Third  woman       False  NaN  Southampton    no  False
# 889        C   First    man        True    C    Cherbourg   yes   True
# 890        Q   Third    man        True  NaN   Queenstown    no   True

# %%
pd.set_option('display.max_columns', None)

# %%
titanic_dataset.iloc[2:10,3:5]
# Out:
#       sex   age
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0
# 5    male   NaN
# 6    male  54.0
# 7    male   2.0
# 8  female  27.0
# 9  female  14.0

# %%
titanic_dataset.iloc[[23,4,6,456]]
# Out:
#      Unnamed: 0  survived  pclass   sex   age  sibsp  parch     fare embarked  \
# 23           23         1       1  male  28.0      0      0  35.5000        S
# 4             4         0       3  male  35.0      0      0   8.0500        S
# 6             6         0       1  male  54.0      0      0  51.8625        S
# 456         456         0       1  male  65.0      0      0  26.5500        S
#
#      class  who  adult_male deck  embark_town alive  alone
# 23   First  man        True    A  Southampton   yes   True
# 4    Third  man        True  NaN  Southampton    no   True
# 6    First  man        True    E  Southampton    no   True
# 456  First  man        True    E  Southampton    no   True

# %%
titanic_dataset.iloc[[23,4,6,456]]
# Out:
#      Unnamed: 0  survived  pclass   sex   age  sibsp  parch     fare embarked  \
# 23           23         1       1  male  28.0      0      0  35.5000        S
# 4             4         0       3  male  35.0      0      0   8.0500        S
# 6             6         0       1  male  54.0      0      0  51.8625        S
# 456         456         0       1  male  65.0      0      0  26.5500        S
#
#      class  who  adult_male deck  embark_town alive  alone
# 23   First  man        True    A  Southampton   yes   True
# 4    Third  man        True  NaN  Southampton    no   True
# 6    First  man        True    E  Southampton    no   True
# 456  First  man        True    E  Southampton    no   True

# %%
titanic_dataset.loc[2:10, 'sex':'age']
# Out:
#        sex   age
# 2   female  26.0
# 3   female  35.0
# 4     male  35.0
# 5     male   NaN
# 6     male  54.0
# 7     male   2.0
# 8   female  27.0
# 9   female  14.0
# 10  female   4.0

# %%
titanic_dataset.loc[titanic_dataset['age']  == 22, 'survived'].sum()
# Out:
# 11
